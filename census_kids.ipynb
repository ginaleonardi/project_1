# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
clean = "clean_master_merge.csv"
clean_df = pd.read_csv(clean)
clean_df
# Out:
#                             SCRAM  ANXIOUS  WORRY  INTEREST  DOWN  EEDUC  \
# 0       V410000001S10011174410111      2.0    2.0       2.0   2.0      7
# 1       V410000001S18010684900121      4.0    4.0       4.0   4.0      7
# 2       V410000001S30011241510121      1.0    1.0       2.0   2.0      5
# 3       V410000001S30011770510111      2.0    1.0       2.0   2.0      6
# 4       V410000001S37010270800121      1.0    1.0       1.0   1.0      7
# ...                           ...      ...    ...       ...   ...    ...
# 821716                 V530068500      2.0    1.0       1.0   1.0      4
# 821717                 V530068501      2.0    2.0       1.0   1.0      3
# 821718                 V530068502      NaN    NaN       NaN   NaN      6
# 821719                 V530068503      1.0    1.0       2.0   2.0      7
# 821720                 V530068504      1.0    1.0       1.0   1.0      6
#
#         RRACE  TBIRTH_YEAR  RHISPANIC  RRACE.1  ...  GENID_DESCRIBE  \
# ...

# %%
#cleaning n/a from feelings columns
#dropping duplicate columns
#renaming columns
clean_df = clean_df.dropna(subset=['ANXIOUS', 'WORRY', 'INTEREST', 'DOWN'])
clean_df = clean_df.drop(['SCRAM', 'RRACE.1','EEDUC.1'], axis=1)
clean_df = clean_df.rename(columns={'TENURE': 'Home Ownership',
                                    'EEDUC': 'Education',
                                    'RRACE': 'Race',
                                    'TBIRTH_YEAR': 'Birth Year',
                                    'RHISPANIC': 'Hispanic',
                                    'MS': 'Martial Status',
                                    'EGENID_BIRTH': 'Gender @ Birth',
                                    'GENID_DESCRIBE': 'Gender Id Describe',
                                    'SEXUAL_ORIENTATION': 'Sexual Orientation',
                                    'ANYWORK': 'Employment Status',
                                    'WEEK': 'Survey Date',
                                    'INCOME': 'Income',
                                    'KIDS_LT5Y': 'Kids 0-4',
                                    'KIDS_5_11Y': 'Kids 5-11',
                                    'KIDS_12_17Y': 'Kids 12-17',
                                    'EST_ST': 'State'})
clean_df
# Out:
#         ANXIOUS  WORRY  INTEREST  DOWN  Education  Race  Birth Year  Hispanic  \
# 0           2.0    2.0       2.0   2.0          7     2        1974         1
# 1           4.0    4.0       4.0   4.0          7     1        1986         1
# 2           1.0    1.0       2.0   2.0          5     1        1986         1
# 3           2.0    1.0       2.0   2.0          6     1        1976         1
# 4           1.0    1.0       1.0   1.0          7     1        1953         1
# ...         ...    ...       ...   ...        ...   ...         ...       ...
# 821715      4.0    4.0       4.0   4.0          5     1        1983         1
# 821716      2.0    1.0       1.0   1.0          4     1        1997         1
# 821717      2.0    2.0       1.0   1.0          3     1        1969         2
# 821719      1.0    1.0       2.0   2.0          7     1        1967         1
# 821720      1.0    1.0       1.0   1.0          6     1        1980         1
#
# ...

# %%
#narrowing down to kids and feelings only
kids_df = clean_df.drop(['Education', 'Race','Birth Year', 'Hispanic', 'Martial Status', 'Gender @ Birth',
                         'Gender Id Describe', 'Sexual Orientation', 'Employment Status', 
                        'Survey Date', 'Income', 'Home Ownership', 'State'], axis=1)
kids_df
# Out:
#         ANXIOUS  WORRY  INTEREST  DOWN  Kids 0-4  Kids 5-11  Kids 12-17
# 0           2.0    2.0       2.0   2.0       NaN        NaN         1.0
# 1           4.0    4.0       4.0   4.0       1.0        1.0         NaN
# 2           1.0    1.0       2.0   2.0       NaN        NaN         NaN
# 3           2.0    1.0       2.0   2.0       NaN        NaN         NaN
# 4           1.0    1.0       1.0   1.0       NaN        NaN         NaN
# ...         ...    ...       ...   ...       ...        ...         ...
# 821715      4.0    4.0       4.0   4.0       NaN        NaN         NaN
# 821716      2.0    1.0       1.0   1.0       NaN        NaN         NaN
# 821717      2.0    2.0       1.0   1.0       NaN        NaN         NaN
# 821719      1.0    1.0       2.0   2.0       NaN        NaN         NaN
# 821720      1.0    1.0       1.0   1.0       NaN        NaN         1.0
#
# [718753 rows x 7 columns]

# %%
#filling n/a with zeros and setting data type
kids_df["Kids 0-4"] = kids_df["Kids 0-4"].fillna(0)
kids_df["Kids 5-11"] = kids_df["Kids 5-11"].fillna(0)
kids_df["Kids 12-17"] = kids_df["Kids 12-17"].fillna(0)
kids_df = kids_df.astype(int)
kids_df
# Out:
#         ANXIOUS  WORRY  INTEREST  DOWN  Kids 0-4  Kids 5-11  Kids 12-17
# 0             2      2         2     2         0          0           1
# 1             4      4         4     4         1          1           0
# 2             1      1         2     2         0          0           0
# 3             2      1         2     2         0          0           0
# 4             1      1         1     1         0          0           0
# ...         ...    ...       ...   ...       ...        ...         ...
# 821715        4      4         4     4         0          0           0
# 821716        2      1         1     1         0          0           0
# 821717        2      2         1     1         0          0           0
# 821719        1      1         2     2         0          0           0
# 821720        1      1         1     1         0          0           1
#
# [718753 rows x 7 columns]

# %%
#narrow down to one feeling
anxious = kids_df['ANXIOUS'].mean()
worry = kids_df['WORRY'].mean()
interest =kids_df['INTEREST'].mean()
down = kids_df['DOWN'].mean()
print(anxious, worry, interest, down)
# Out:
# 1.9501094256302234 1.7694089624669394 1.6874893043924686 1.6767192623891656

# %%
#sort out with no kids only
no_kids = kids_df.loc[(kids_df['Kids 0-4'] == 0) & (kids_df['Kids 5-11'] == 0) & (kids_df['Kids 12-17'] == 0), :]
no_kids
# Out:
#         ANXIOUS  WORRY  INTEREST  DOWN  Kids 0-4  Kids 5-11  Kids 12-17
# 2             1      1         2     2         0          0           0
# 3             2      1         2     2         0          0           0
# 4             1      1         1     1         0          0           0
# 6             4      4         1     4         0          0           0
# 9             1      1         1     1         0          0           0
# ...         ...    ...       ...   ...       ...        ...         ...
# 821714        3      2         1     2         0          0           0
# 821715        4      4         4     4         0          0           0
# 821716        2      1         1     1         0          0           0
# 821717        2      2         1     1         0          0           0
# 821719        1      1         2     2         0          0           0
#
# [509655 rows x 7 columns]

# %%
no_kids["ANXIOUS"].value_counts()
# Out:
# 1    231362
# 2    165581
# 4     63040
# 3     49672
# Name: ANXIOUS, dtype: int64

# %%
anx_no_kids = no_kids["ANXIOUS"].value_counts()
anx_no_kids.plot(kind="bar")
plt.title("Anxiety Score with no Kids")
plt.xlabel("Anxiety Score")
plt.ylabel("Anxiety Score Count")
plt.xticks(rotation="vertical")
plt.ylim(0, 250000)
plt.savefig("Anxietynokids.png", bbox_inches='tight')
plt.show()

# %%
#sorting to with kids only
with_kids = kids_df.loc[(kids_df['Kids 0-4'] == 1) | (kids_df['Kids 5-11'] == 1) | (kids_df['Kids 12-17'] == 1), :]
with_kids
# Out:
#         ANXIOUS  WORRY  INTEREST  DOWN  Kids 0-4  Kids 5-11  Kids 12-17
# 0             2      2         2     2         0          0           1
# 1             4      4         4     4         1          1           0
# 8             1      1         2     1         0          1           1
# 10            3      2         2     2         0          1           1
# 16            3      2         1     2         1          1           1
# ...         ...    ...       ...   ...       ...        ...         ...
# 821707        2      2         2     2         1          0           0
# 821708        4      4         4     2         0          1           1
# 821709        3      2         1     2         1          1           0
# 821710        1      2         1     1         0          0           1
# 821720        1      1         1     1         0          0           1
#
# [209098 rows x 7 columns]

# %%
anx_with_kids = with_kids["ANXIOUS"].value_counts()
anx_with_kids.plot(kind="bar")
plt.title("Anxiety Score with Kids")
plt.xlabel("Anxiety Score")
plt.ylabel("Anxiety Score Count")
plt.xticks(rotation="vertical")
plt.ylim(0, 250000)
plt.savefig("Anxietywithkids.png", bbox_inches='tight')
plt.show()

# %%
#narrow down further to highest reported feeling and greatest number
no_kids4 = no_kids.loc[no_kids["ANXIOUS"] == 4]
no_kids4
# Out:
#         ANXIOUS  WORRY  INTEREST  DOWN  Kids 0-4  Kids 5-11  Kids 12-17
# 6             4      4         1     4         0          0           0
# 25            4      4         4     2         0          0           0
# 44            4      4         3     2         0          0           0
# 74            4      2         1     1         0          0           0
# 86            4      4         2     3         0          0           0
# ...         ...    ...       ...   ...       ...        ...         ...
# 821596        4      4         4     4         0          0           0
# 821636        4      3         2     2         0          0           0
# 821680        4      4         4     4         0          0           0
# 821704        4      3         3     4         0          0           0
# 821715        4      4         4     4         0          0           0
#
# [63040 rows x 7 columns]

# %%
#narrow down further to highest reported feeling and greatest number
with_kids4 = with_kids.loc[with_kids["ANXIOUS"] == 4]
with_kids4
# Out:
#         ANXIOUS  WORRY  INTEREST  DOWN  Kids 0-4  Kids 5-11  Kids 12-17
# 1             4      4         4     4         1          1           0
# 28            4      4         4     4         0          1           0
# 90            4      3         2     1         1          0           0
# 93            4      4         1     2         1          1           1
# 97            4      4         4     4         1          0           0
# ...         ...    ...       ...   ...       ...        ...         ...
# 821554        4      3         3     3         0          1           1
# 821570        4      3         3     3         0          1           1
# 821620        4      3         2     2         1          1           0
# 821623        4      2         3     2         0          1           1
# 821708        4      4         4     2         0          1           1
#
# [33742 rows x 7 columns]

# %%
#make a new column that lumps all 3 kid questions columns into one
no_kids4['Kids'] = 0

# %%
no_kids4
# Out:
#         ANXIOUS  WORRY  INTEREST  DOWN  Kids 0-4  Kids 5-11  Kids 12-17  Kids
# 6             4      4         1     4         0          0           0     0
# 25            4      4         4     2         0          0           0     0
# 44            4      4         3     2         0          0           0     0
# 74            4      2         1     1         0          0           0     0
# 86            4      4         2     3         0          0           0     0
# ...         ...    ...       ...   ...       ...        ...         ...   ...
# 821596        4      4         4     4         0          0           0     0
# 821636        4      3         2     2         0          0           0     0
# 821680        4      4         4     4         0          0           0     0
# 821704        4      3         3     4         0          0           0     0
# 821715        4      4         4     4         0          0           0     0
#
# [63040 rows x 8 columns]

# %%
#group by new kids column
kids_no = no_kids4.groupby('Kids')

# %%
#create new dataframe to verify highest reported feeling
average_nokids = kids_no[["ANXIOUS", "WORRY", "INTEREST", "DOWN"]].mean()

average_nokids
# Out:
#       ANXIOUS     WORRY  INTEREST      DOWN
# Kids
# 0         4.0  3.472303  3.029632  3.108201

# %%
#make a new column that lumps all 3 kid questions columns into one
with_kids4['Kids'] = 1

# %%
with_kids4
# Out:
#         ANXIOUS  WORRY  INTEREST  DOWN  Kids 0-4  Kids 5-11  Kids 12-17  Kids
# 1             4      4         4     4         1          1           0     1
# 28            4      4         4     4         0          1           0     1
# 90            4      3         2     1         1          0           0     1
# 93            4      4         1     2         1          1           1     1
# 97            4      4         4     4         1          0           0     1
# ...         ...    ...       ...   ...       ...        ...         ...   ...
# 821554        4      3         3     3         0          1           1     1
# 821570        4      3         3     3         0          1           1     1
# 821620        4      3         2     2         1          1           0     1
# 821623        4      2         3     2         0          1           1     1
# 821708        4      4         4     2         0          1           1     1
#
# [33742 rows x 8 columns]

# %%
#group by new kids column
kids_yes = with_kids4.groupby('Kids')

# %%
#create new dataframe to verify highest reported feeling
average_withkids = kids_yes[["ANXIOUS", "WORRY", "INTEREST", "DOWN"]].mean()

average_withkids
# Out:
#       ANXIOUS     WORRY  INTEREST      DOWN
# Kids
# 1         4.0  3.500978  2.950418  3.005364

# %%
#merge both for plotting only interested in new kid column and anxious column 
final = pd.merge(no_kids4, with_kids4, how="outer", on=["Kids", "ANXIOUS"])

# %%
final
# Out:
#        ANXIOUS  WORRY_x  INTEREST_x  DOWN_x  Kids 0-4_x  Kids 5-11_x  \
# 0            4      4.0         1.0     4.0         0.0          0.0
# 1            4      4.0         4.0     2.0         0.0          0.0
# 2            4      4.0         3.0     2.0         0.0          0.0
# 3            4      2.0         1.0     1.0         0.0          0.0
# 4            4      4.0         2.0     3.0         0.0          0.0
# ...        ...      ...         ...     ...         ...          ...
# 96777        4      NaN         NaN     NaN         NaN          NaN
# 96778        4      NaN         NaN     NaN         NaN          NaN
# 96779        4      NaN         NaN     NaN         NaN          NaN
# 96780        4      NaN         NaN     NaN         NaN          NaN
# 96781        4      NaN         NaN     NaN         NaN          NaN
#
#        Kids 12-17_x  Kids  WORRY_y  INTEREST_y  DOWN_y  Kids 0-4_y  \
# 0               0.0     0      NaN         NaN     NaN         NaN
# ...

# %%
kidsy_n = final["Kids"].value_counts()
kidsy_n.plot(kind="pie", autopct="%1.1f%%", labels=["No Kids", "With Kids"])
plt.ylabel('Anxious 4 by Kids')
plt.savefig("Anxiety4kids.png", bbox_inches='tight')
plt.show()
